# %% [markdown]
# <a href="https://colab.research.google.com/github/hj-1006/hj_pyton_study/blob/main/07_%EB%8D%B0%EC%9D%B4%ED%84%B0_%EC%8B%9C%EA%B0%81%ED%99%94.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 매스플로잇으로 데이터 차트 생성

# %%
# 7-1 챠트 생성]
import matplotlib.pyplot as plt
plt.title('Korea')
plt.plot([-1,2,3,4])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#7-2 한글 폰트 설치
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# fonts-nanum is already the newest version (20200506-1).
# 0 upgraded, 0 newly installed, 0 to remove and 45 not upgraded.
# /usr/share/fonts: caching, new cache contents: 0 fonts, 1 dirs
# /usr/share/fonts/truetype: caching, new cache contents: 0 fonts, 3 dirs
# /usr/share/fonts/truetype/humor-sans: caching, new cache contents: 1 fonts, 0 dirs
# /usr/share/fonts/truetype/liberation: caching, new cache contents: 16 fonts, 0 dirs
# /usr/share/fonts/truetype/nanum: caching, new cache contents: 12 fonts, 0 dirs
# /usr/local/share/fonts: caching, new cache contents: 0 fonts, 0 dirs
# /root/.local/share/fonts: skipping, no such directory
# /root/.fonts: skipping, no such directory
# /usr/share/fonts/truetype: skipping, looped directory detected
# /usr/share/fonts/truetype/humor-sans: skipping, looped directory detected
# ...

# %%
# 7-3 한글폰트 설치
import matplotlib.pyplot as plt
plt.rc('font',family='NanumGothic')
plt.rcParams['axes.unicode_minus'] = False

plt.plot([-1,2,3,4])
plt.title('대한민국')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# 7-4 축 범위 지정
year = [2014, 2017, 2020, 2023]
price = [25000, 31000, 53000, 63000]
plt.plot(year,price,'y-.^')
#       (x축, y축 , 포멧스타일)
# 색상 b,g,r,c,y,k,w
# 선종류 -(실선) --(파선) -.(일점쇄선) :(점선)
# 마커 모양 o(원) +(십자가) D(다이아몬드) s(사각형) ^(삼각형) v(역삼각형) .(점)

plt.axis([2013,2024,20000,70000])
plt.show()

# %%
#7-5 차트 하나에 그래프 세 개 생성
import numpy as np

a = np.random.randn(10)
b = np.random.randn(10)*2
c = np.random.randn(10)*10

plt.plot(a, 'r-^',label='one')
plt.plot(b, 'b--v',label='two')
plt.plot(c, 'g:s',label='three')

# print('a는 :', a)
# print('b는 :', b)
# print('c는 :', c)

plt.legend()

plt.gca().yaxis.set_major_formatter(plt.FormatStrFormatter('%.2f'))

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
 #7-6 다중 그래프
plt.subplot(2,2,1)
plt.plot(np.random.randn(10),'b--o')
plt.subplot(2,2,2)
plt.plot(np.random.randn(100),'r',alpha=0.7) # alpha는 투명도를 의미함
plt.subplot(2,2,3)
plt.plot(np.random.randn(10),'y^--')
plt.subplot(2,2,4)
plt.plot(np.random.randn(10),'g-..')
plt.show()

# %%
#7-7 연도별 상품가격 _산점도_
year = [2014,2017,2020,2023]
price = [25000,31000,53000,63000]
plt.scatter(year,price,c='r',s=100,marker='.')
plt.show()

# %%
#7-8 주사위 결과 히스토그램
numbers = [5,4,4,1,6,3,4,1,2,2]
plt.hist(numbers, bins=6)
plt.show()

# %%
#7-8 주사위 100번 돌려 히스토그램 만들기
numbers = np.random.randint(1, 7, 100)
print(numbers)
plt.hist(numbers, bins=6)
plt.show()
# Out:
# [2 6 4 3 1 5 2 6 4 1 3 2 5 2 2 5 5 6 4 5 4 5 6 5 5 3 1 1 4 6 3 2 6 2 2 1 1
#  4 1 5 4 4 5 5 5 1 6 6 4 5 5 1 5 3 4 3 6 5 3 2 5 3 3 5 4 3 3 3 4 3 2 4 5 5
#  1 2 6 5 6 4 4 2 5 6 4 1 1 1 5 1 2 3 2 3 1 5 4 3 4 1]

# %%
#7-9 상자 그래프 (표준편차값)
numbers = [0, 1.4, 1.6, 1.8, 1.85, 1.9, 2.2, 2.5, 5.7, 9]
plt.boxplot(numbers)
plt.show()

# %%
#7-10 과목별 성적 막대 그래프
subject = ['KOR', 'ENG', 'MATH']
grade = [85,76,55]

plt.title('Report')
plt.xlabel('Subject')
plt.ylabel('Grade')

plt.bar(subject,grade)
plt.ylim(0,100)
plt.text(0,90,'Good!')
plt.show()

# %%
#7-11 과일 소비량 파이 차트
import pandas as pd

exemple_series = pd.Series([20, 15, 5, 5, 10],index=['Apple','Banana','Cherry','Kiwi','Grape'])
print(exemple_series)
plt.pie(exemple_series, labels = exemple_series.index, autopct='%.1f%%')
plt.show()
# Out:
# Apple     20
# Banana    15
# Cherry     5
# Kiwi       5
# Grape     10
# dtype: int64

# %%
#7-11 주사위 파이 차트
import pandas as pd
import numpy as np

dice = np.random.randint(1, 7, 100)
unique_value, value_counts = np.unique(dice, return_counts=True)

plt.pie(value_counts, labels = unique_value , autopct='%.1f%%')
plt.show()

# %%
#7-17 데이터프레임을 네트워크 그래프로 변환
import pandas as pd
import networkx as nx

g4 = nx.DiGraph()
df = pd.DataFrame({'from':['A','B','C','A','E','D'],\
                  'to':['D','A','E','C','A','E'],\
                  'weight':[1,2,3,4,5,6]})
g4 = nx.from_pandas_edgelist(df,'from','to','weight')
pos = nx.spring_layout(g4)
nx.draw(g4, pos=pos, with_labels=True)

labels = nx.get_edge_attributes(g4,'weight')
nx.draw_networkx_edge_labels(g4,pos,edge_labels=labels)
df
# Out:
#   from to  weight
# 0    A  D       1
# 1    B  A       2
# 2    C  E       3
# 3    A  C       4
# 4    E  A       5
# 5    D  E       6

# %%
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# fonts-nanum is already the newest version (20200506-1).
# 0 upgraded, 0 newly installed, 0 to remove and 45 not upgraded.
# /usr/share/fonts: caching, new cache contents: 0 fonts, 1 dirs
# /usr/share/fonts/truetype: caching, new cache contents: 0 fonts, 3 dirs
# /usr/share/fonts/truetype/humor-sans: caching, new cache contents: 1 fonts, 0 dirs
# /usr/share/fonts/truetype/liberation: caching, new cache contents: 16 fonts, 0 dirs
# /usr/share/fonts/truetype/nanum: caching, new cache contents: 12 fonts, 0 dirs
# /usr/local/share/fonts: caching, new cache contents: 0 fonts, 0 dirs
# /root/.local/share/fonts: skipping, no such directory
# /root/.fonts: skipping, no such directory
# /usr/share/fonts/truetype: skipping, looped directory detected
# /usr/share/fonts/truetype/humor-sans: skipping, looped directory detected
# ...

# %%
#7-19 데이터 확인
import matplotlib.pyplot as plt
import pandas as pd

df = pd.read_csv('기온2023.csv',encoding='cp949')
df.head(3)
# Out:
#     지점 지점명          일시  평균기온(°C)  최저기온(°C)  최저기온 시각(hhmi)  최고기온(°C)  \
# 0  108  서울  2023-01-01      -0.2      -4.3           2350       3.8
# 1  108  서울  2023-01-02      -4.5      -7.4            804      -0.4
# 2  108  서울  2023-01-03      -5.0      -9.0            551       0.6
#
#    최고기온 시각(hhmi)
# 0           1343
# 1           1525
# 2           1555
